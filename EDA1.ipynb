# %% [markdown]
# <a href="https://colab.research.google.com/github/Bbrnn/engage_datascience_ai_ml/blob/main/EDA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from statsmodels.graphics.mosaicplot import mosaic

# %%
df = pd.read_csv("/content/nhanes_reduced .csv")

# %%
df.head()
# Out:
#       ID SurveyYr  Gender  Age AgeDecade  AgeMonths     Education  \
# 0  51624  2009_10    male   34     30-39      409.0   High School
# 1  51625  2009_10    male    4       0-9       49.0           NaN
# 2  51630  2009_10  female   49     40-49      596.0  Some College
# 3  51638  2009_10    male    9       0-9      115.0           NaN
# 4  51646  2009_10    male    8       0-9      101.0           NaN
#
#   MaritalStatus     HHIncome  HHIncomeMid  ...  PhysActiveDays  TVHrsDay  \
# 0       Married  25000-34999      30000.0  ...             NaN       NaN
# 1           NaN  20000-24999      22500.0  ...             NaN       NaN
# 2   LivePartner  35000-44999      40000.0  ...             NaN       NaN
# 3           NaN  75000-99999      87500.0  ...             NaN       NaN
# 4           NaN  55000-64999      60000.0  ...             NaN       NaN
#
#   SleepHrsNight SleepTrouble  CompHrsDay  TVHrsDayChild  CompHrsDayChild  \
# ...

# %%
df.tail(4)
# Out:
#          ID SurveyYr  Gender  Age AgeDecade  AgeMonths       Education  \
# 6775  71909  2011_12    male   28     20-29        NaN  9 - 11th Grade
# 6776  71910  2011_12  female    0       0-9        5.0             NaN
# 6777  71911  2011_12    male   27     20-29        NaN    College Grad
# 6778  71915  2011_12    male   60     60-69        NaN    College Grad
#
#      MaritalStatus     HHIncome  HHIncomeMid  ...  PhysActiveDays  TVHrsDay  \
# 6775  NeverMarried    5000-9999       7500.0  ...             NaN      1_hr
# 6776           NaN  75000-99999      87500.0  ...             NaN       NaN
# 6777       Married  75000-99999      87500.0  ...             3.0      1_hr
# 6778  NeverMarried  65000-74999      70000.0  ...             1.0      2_hr
#
#      SleepHrsNight SleepTrouble  CompHrsDay  TVHrsDayChild  CompHrsDayChild  \
# 6775           6.0           No        2_hr            NaN              NaN
# ...

# %% [markdown]
# # Columns
# * Returns a list of column names present in the DataFrame.
# * Useful for quickly checking what columns are available for analysis.

# %% [markdown]
# ####In Object-Oriented Programming, attributes and methods are key components of objects (like DataFrames in Pandas).
#
# **Attributes:**
#
# Represent the characteristics or properties of an object.
# Store data associated with the object.
# In Pandas, examples include df.shape (dimensions of the DataFrame), df.columns (column names), etc.
#
# **Methods:**
#
# Define the actions or behaviors that an object can perform.
# Are functions associated with an object.
# In Pandas, examples include df.head() (display first few rows), df.describe() (summary statistics), etc.
# Key Difference: Attributes store data, while methods perform actions on the object.
#
# *For example:*
#
# df.shape is an attribute that stores the dimensions of the DataFrame.
# df.sort_values() is a method that sorts the DataFrame based on specified columns.
# Think of it like a car:
#
# **Attributes are like its color, number of seats, etc.
# Methods are like starting the engine, accelerating, braking, etc.**

# %%
df.columns
# Out:
# Index(['ID', 'SurveyYr', 'Gender', 'Age', 'AgeDecade', 'AgeMonths',
#        'Education', 'MaritalStatus', 'HHIncome', 'HHIncomeMid', 'Poverty',
#        'HomeRooms', 'HomeOwn', 'Work', 'Weight', 'Height', 'BMI', 'BMI_WHO',
#        'DirectChol', 'TotChol', 'Diabetes', 'DiabetesAge', 'HealthGen',
#        'nPregnancies', 'nBabies', 'Age1stBaby', 'PhysActive', 'PhysActiveDays',
#        'TVHrsDay', 'SleepHrsNight', 'SleepTrouble', 'CompHrsDay',
#        'TVHrsDayChild', 'CompHrsDayChild', 'SmokeNow', 'Smoke100',
#        'Smoke100n'],
#       dtype='object')

# %%
df.shape
# Out:
# (6779, 37)

# %% [markdown]
# # info()
# Provides a concise summary of the DataFrame, including:
# * Number of rows and columns
# * Column names and their data types
# * Number of non-null values in each column
# * Memory usage of the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6779 entries, 0 to 6778
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               6779 non-null   int64
#  1   SurveyYr         6779 non-null   object
#  2   Gender           6779 non-null   object
#  3   Age              6779 non-null   int64
#  4   AgeDecade        6530 non-null   object
#  5   AgeMonths        3549 non-null   float64
#  6   Education        4645 non-null   object
#  7   MaritalStatus    4650 non-null   object
#  8   HHIncome         6194 non-null   object
#  9   HHIncomeMid      6194 non-null   float64
#  10  Poverty          6261 non-null   float64
#  11  HomeRooms        6731 non-null   float64
#  12  HomeOwn          6735 non-null   object
#  13  Work             5046 non-null   object
#  14  Weight           6724 non-null   float64
#  15  Height           6481 non-null   float64
# ...

# %%
nhanes = df['Education'].value_counts()
print(nhanes)
# Out:
# Education
# Some College      1423
# College Grad      1246
# High School        993
# 9 - 11th Grade     624
# 8th Grade          359
# Name: count, dtype: int64

# %%
df.sort_values(by = 'Age', ascending = False)
# Out:
#          ID SurveyYr  Gender  Age AgeDecade  AgeMonths     Education  \
# 5541  68115  2011_12  female   80       NaN        NaN  Some College
# 693   53576  2009_10  female   80       NaN        NaN     8th Grade
# 3753  62727  2011_12  female   80       NaN        NaN  Some College
# 4524  65051  2011_12  female   80       NaN        NaN     8th Grade
# 2990  60371  2009_10  female   80       NaN        NaN  Some College
# ...     ...      ...     ...  ...       ...        ...           ...
# 6628  71463  2011_12    male    0       0-9        4.0           NaN
# 1831  56995  2009_10    male    0       0-9        0.0           NaN
# 2605  59212  2009_10  female    0       0-9        2.0           NaN
# 1286  55334  2009_10  female    0       0-9       11.0           NaN
# 3363  61553  2009_10    male    0       0-9       11.0           NaN
#
#      MaritalStatus     HHIncome  HHIncomeMid  ...  PhysActiveDays   TVHrsDay  \
# ...

# %% [markdown]
# In pandas, the pd.crosstab() function computes a cross-tabulation (also known as a contingency table) of two or more factors. It summarizes the relationship between these factors by showing the frequency distribution of each combination of factor levels.

# %%
freq_table = pd.crosstab(df['Gender'], 'Bridget')
print(freq_table)
# Out:
# col_0   Bridget
# Gender
# female     3420
# male       3359

# %%
freq_table = pd.crosstab(df['Education'],df['HHIncome'])
freq_table
# Out:
# HHIncome        0-4999  10000-14999  15000-19999  20000-24999  25000-34999  \
# Education
# 8th Grade           15           35           46           45           55
# 9 - 11th Grade      26           64           57           61           77
# College Grad        13           14           31           25           66
# High School         21           95           74           80          119
# Some College        23           90           70           86          149
#
# HHIncome        35000-44999  45000-54999  5000-9999  55000-64999  65000-74999  \
# Education
# 8th Grade                32           17         23           12            8
# 9 - 11th Grade           56           46         34           32           25
# College Grad             85           80          8           75           81
# High School             114           86         35           62           46
# Some College            136          128         33           92           85
#
# ...

# %%
row_percentages = freq_table.apply(lambda row: row/row.sum(), axis=1)
print(row_percentages)
# Out:
# HHIncome          0-4999  10000-14999  15000-19999  20000-24999  25000-34999  \
# Education
# 8th Grade       0.049342     0.115132     0.151316     0.148026     0.180921
# 9 - 11th Grade  0.047532     0.117002     0.104205     0.111517     0.140768
# College Grad    0.011102     0.011956     0.026473     0.021349     0.056362
# High School     0.023230     0.105088     0.081858     0.088496     0.131637
# Some College    0.017638     0.069018     0.053681     0.065951     0.114264
#
# HHIncome        35000-44999  45000-54999  5000-9999  55000-64999  65000-74999  \
# Education
# 8th Grade          0.105263     0.055921   0.075658     0.039474     0.026316
# 9 - 11th Grade     0.102377     0.084095   0.062157     0.058501     0.045704
# College Grad       0.072588     0.068318   0.006832     0.064048     0.069172
# High School        0.126106     0.095133   0.038717     0.068584     0.050885
# Some College       0.104294     0.098160   0.025307     0.070552     0.065184
#
# ...

# %% [markdown]
# ##Plotting pie chart of the education level
# plt.pie(Education_counts, ...):** Creates a pie chart using the values from Education_counts.
#
# **labels=Education_counts.index:** Sets the labels for each slice of the pie chart to the index (likely the education levels) of the Education_counts Series.
#
# **autopct='%1.1f%%':** Formats the percentage labels on each slice to display one decimal place.
#
# **startangle=90:** Rotates the pie chart so that the first slice starts at the 90-degree position (top).

# %%
#Drawing a pie chart for education
Education_counts = df['Education'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(Education_counts, labels=Education_counts.index, autopct='%1.1f%%', startangle=40)
plt.title('Education Distribution')
plt.show()

# %% [markdown]
# #Plotting bar charts

# %%
data ={'C':20, 'C++':15,'Java':30,'Python':35}
courses = list(data.keys())
values = list(data.values())
fig = plt.figure(figsize = (10, 5))
plt.bar(courses, values, color ='red',
width = 0.4)
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.barh(courses,values,color="maroon")
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# #SIDE BY SIDE BAR CHART

# %%
# Group by 'HHIncome' and 'Education', count occurrences, and unstack
grouped_data = df.groupby(['HHIncome', 'Education']).size().unstack()

#plot grouped bar chart
grouped_data.plot(kind='bar', figsize=(10,6))

#set labels and titles
plt.xlabel('HHIncome')
plt.ylabel('Count')
plt.xticks(rotation=45) #rotate x axis labels
plt.legend(title = 'Education')
plt.title('Grouped Bar Chart of HHIncome and Education')
plt.tight_layout()#to adjust the spacing of plot elements to prevent labels ,titles and other elements from overlapping

#show the plot
plt.show()

# %% [markdown]
# #MOSAIC PLOT

# %% [markdown]
# #STACKED BAR CHARTS

# %%
# Group by 'HHIncome' and 'Education', count occurrences, and unstack
grouped_data = df.groupby(['HHIncome', 'Education']).size().unstack()

#plot stacked bar chart
grouped_data.plot(kind='bar',stacked=True,figsize=(10,6))

#set labels and titles
plt.xlabel('HHIncome')
plt.ylabel('Count')
plt.xticks(rotation=45) #rotate x axis labels
plt.legend(title = 'Education')
plt.title('Stacked Bar Chart of HHIncome and Education')
plt.tight_layout()#to adjust the spacing of plot elements to prevent labels ,titles and other elements from overlapping

#show the plot
plt.show()

# %% [markdown]
# #FACETED PLOT

# %%
education_groups = df['Education'].unique()

#create subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(18,10))
axes = axes.flatten()

#plot each age groups education level distribution
for i, education_group in enumerate(education_groups):
  ax = axes[i]
  #filter data for the current education level subgroups
  subset = df[df['Education']==education_group]
   # Assuming 'AgeDecade' is the column representing age groups
  sns.countplot(data=subset, x='AgeDecade', ax=ax)

  ax.set_title(f'Education Level: {education_group}')
  ax.set_xlabel('Age Decade')
  ax.set_ylabel('Count')

#tight layout
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-87-e7b29b6883cc> in <cell line: 8>()
#       7 #plot each age groups education level distribution
#       8 for i, education_group in enumerate(education_groups):
# ----> 9   ax = axes[i]
#      10   #filter data for the current education level subgroups
#      11   subset = df[df['Education']==education_group]
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %% [markdown]
# #Scatter plots

# %%
data ={'x':[1,2,3,4,5,6,7],
       'y':[2,5,7,4,3,1,1]}
scat = pd.DataFrame(data)
#plot scatter plot
plt.scatter(x='x',y='y',data=scat)
plt.show()

# %%
data ={'x':[1,2,3,4,5,6,7],
       'y':[1,2,3,4,5,6,7]}
scat1 = pd.DataFrame(data)
#plot scatter plot
plt.scatter(x='x',y='y',data=scat1)
plt.show()

# %%
plt.scatter(df['Age'],df['AgeMonths'],color='blue')

# %% [markdown]
# #HISTOGRAM

# %%
plt.figure(figsize=(10,6))
plt.hist(df['SleepHrsNight'].dropna(),bins=10,color='green')

plt.show()

# %% [markdown]
# #BOX PLOT

# %%
  sns.boxplot(x='HHIncome',y='BMI',data=df)
  plt.title('Boxplot of HHIncome vs BMI')
  plt.xlabel('HHIncome')
  plt.ylabel('BMI')
  plt.xticks(rotation=45)
  plt.show()

# %%
  sns.boxplot(x='HHIncome',data=df)
  plt.title('Boxplot of HHIncome')
  plt.xlabel('HHIncome')
  plt.xticks(rotation=45)
  plt.show()

# %%
  #box plot on age
  sns.boxplot(x='Age',data=df)
  plt.title('Boxplot of Age')
  plt.xlabel('Age')
  plt.xticks(rotation=45)
  plt.show()

# %%
#box plot ON AGE decade versus BMI
sns.boxplot(x='AgeDecade',y='BMI',data=df)
plt.title('Boxplot of AgeDecade vs BMI')
plt.xlabel('AgeDecade')
plt.ylabel('BMI')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #KDE PLOT

# %%
df['AgeDecade'].unique()
# Out:
# array(['30-39', '0-9', '40-49', '60-69', '50-59', 'Oct-19', '20-29', '70',
#        nan], dtype=object)

# %%
#KDE PLOT
sns.kdeplot(data=df,x='BMI',hue='Work',multiple='stack')
plt.show()

# %% [markdown]
# #SWEETVIZ

# %%
pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 46.2 MB/s eta 0:00:00
# ...

# %%
import sweetviz as sv

my_report = sv.analyze(df)
my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# #YDATA PROFILING

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_file("your_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
