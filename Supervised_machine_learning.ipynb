# %% [markdown]
# <a href="https://colab.research.google.com/github/Bbrnn/engage_datascience_ai_ml/blob/main/Supervised_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('/content/child_data .xlsx')

# %%
data
# Out:
#      Age (months)  Sex  Mother's education  Area  Wealth index quintile  \
# 0              45    0                   1     0                      0
# 1              45    1                   0     0                      1
# 2              36    1                   0     0                      2
# 3              51    0                   0     0                      2
# 4              56    0                   0     0                      2
# ..            ...  ...                 ...   ...                    ...
# 763             7    0                   0     1                      2
# 764             0    1                   1     1                      2
# 765            56    0                   0     1                      2
# 766            18    0                   0     1                      2
# 767             7    0                   0     1                      4
#
#      Child's weight (kilograms)
# 0                          16.2
# 1                          13.5
# ...

# %%
data.columns
# Out:
# Index(['Age (months)', 'Sex', 'Mother's education', 'Area',
#        'Wealth index quintile', 'Child's weight (kilograms)'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Age (months)                  0
# Sex                           0
# Mother's education            0
# Area                          0
# Wealth index quintile         0
# Child's weight (kilograms)    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age (months)                768 non-null    int64
#  1   Sex                         768 non-null    int64
#  2   Mother's education          768 non-null    int64
#  3   Area                        768 non-null    int64
#  4   Wealth index quintile       768 non-null    int64
#  5   Child's weight (kilograms)  768 non-null    float64
# dtypes: float64(1), int64(5)
# memory usage: 36.1 KB

# %%
data.describe()
# Out:
#        Age (months)         Sex  Mother's education        Area  \
# count    768.000000  768.000000          768.000000  768.000000
# mean      29.151042    0.494792            0.380208    0.445312
# std       16.861367    0.500299            0.485754    0.497324
# min        0.000000    0.000000            0.000000    0.000000
# 25%       14.000000    0.000000            0.000000    0.000000
# 50%       30.000000    0.000000            0.000000    0.000000
# 75%       43.000000    1.000000            1.000000    1.000000
# max       59.000000    1.000000            1.000000    1.000000
#
#        Wealth index quintile  Child's weight (kilograms)
# count             768.000000                  768.000000
# mean                2.010417                   11.593490
# std                 1.379642                    3.408997
# min                 0.000000                    3.200000
# 25%                 1.000000                    9.200000
# ...

# %%
data.corr()
data.corr(method='spearman')
# Out:
#                             Age (months)       Sex  Mother's education  \
# Age (months)                    1.000000 -0.037450           -0.060813
# Sex                            -0.037450  1.000000            0.029619
# Mother's education             -0.060813  0.029619            1.000000
# Area                           -0.027959  0.046014            0.161740
# Wealth index quintile          -0.007962 -0.079103           -0.206120
# Child's weight (kilograms)      0.842079  0.038508            0.007792
#
#                                 Area  Wealth index quintile  \
# Age (months)               -0.027959              -0.007962
# Sex                         0.046014              -0.079103
# Mother's education          0.161740              -0.206120
# Area                        1.000000              -0.225187
# Wealth index quintile      -0.225187               1.000000
# Child's weight (kilograms)  0.033214              -0.083013
#
# ...

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#data.plot(kind='scatter',x= "Age (months)", y= "Child's weight (kilograms)",s=32,alpha=8)
sns.scatterplot(data=data,x= "Age (months)", y= "Child's weight (kilograms)")
plt.title("Scatter plot")
plt.xlabel("Age (months)")
plt.ylabel("Child's weight")
plt.show()

# %%
#Create dependent and independent variables
x = data[["Age (months)"]]#independent variable
y = data[["Child's weight (kilograms)"]]#dependent variable
# Out:
#      Child's weight (kilograms)
# 0                          16.2
# 1                          13.5
# 2                          13.4
# 3                          15.0
# 4                          15.2
# ..                          ...
# 763                         8.3
# 764                         3.5
# 765                        15.1
# 766                        10.7
# 767                        10.3
#
# [768 rows x 1 columns]

# %%
x
# Out:
#      Age (months)
# 0              45
# 1              45
# 2              36
# 3              51
# 4              56
# ..            ...
# 763             7
# 764             0
# 765            56
# 766            18
# 767             7
#
# [768 rows x 1 columns]

# %%
y
# Out:
#      Child's weight (kilograms)
# 0                          16.2
# 1                          13.5
# 2                          13.4
# 3                          15.0
# 4                          15.2
# ..                          ...
# 763                         8.3
# 764                         3.5
# 765                        15.1
# 766                        10.7
# 767                        10.3
#
# [768 rows x 1 columns]

# %%
from sklearn  import linear_model
from sklearn.model_selection import train_test_split

model = linear_model.LinearRegression()

X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# #Training the model

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #PREDICT the model

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# #Compare the actual vlaues with the predicted values

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test,y_test,label = "Actual values", color = "red",marker=".")
plt.plot(X_test,y_pred,label = "Predicted values", color = "blue")
plt.legend()
plt.title("Actual vs Predicted values")
plt.xlabel("Age (months)")
plt.ylabel("Child's weight (kilograms)")
plt.show()
